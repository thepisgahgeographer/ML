# %%
import numpy as np
np

# %%
#np.sin(np.array([1, 2, 3]))
arr = np.array([1, 2, 3])
arr

# %%
type(arr[1])

# %%
arr1 = np.arange(10)
arr1

# %%
arr2 = arr1.reshape(5,2)
arr2

# %%
arr2[2,0] = 10
arr2

# %%
arr2[:3]

# %%
arr2[(arr2> 3) & (arr2<6)]

# %%
mat = np.arange(9).reshape((3,3))
vec = np.arange(3)

mat + vec

# %%
test = np.array([1, 4, 9, 12])
test

# %%
test2 = test.reshape(2,2)
test2

# %%
test2.T

# %%
#test2.any()
test2[1,1]

# %%
test2.shape

# %%
a = np.arange(15).reshape(3,5)
a

# %%
ones = np.ones([2,4])
ones.sum(axis=1)

# %%
ones

# %%
print(a)
a[2,4]

# %%
data = np.array([[1, 2], [3, 4], [5, 6]])
data.max(axis=1)

# %%
rng = np.random.default_rng()
numbs = rng.integers(20, size=(3,4))
np.unique(numbs)

# %%
import os
import tarfile
import urllib

# DOWNLOAD_ROOT = "https://github.com/thepisgahgeographer/ArcGIS_JS_API/blob/cebf11378fc11b459ea25e984561ca6c739a52ed/Add_Layers.html"
# HOUSING_PATH = os.path.join("datasets", "housing")
# #HOUSING_URL = DOWNLOAD_ROOT + "ML/datasets/housing/housing.tgz"

# def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
#     os.makedirs(housing_path, exist_ok=True)
#     tgz_path = os.path.join(housing_path, "housing.tgz")
#     urllib.request.urlretrieve(housing_url, tgz_path)
#     housing_tgz = tarfile.open(tgz_path)
#     housing_tgz.extractall(path=housing_path)
#     housing_tgz.close()

DOWNLOAD_ROOT = "https://github.com/thepisgahgeographer/ArcGIS_JS_API/blob/cebf11378fc11b459ea25e984561ca6c739a52ed/Add_Layers.html"
HOUSING_PATH = r"C:/Data"

def fetch_housing_data(housing_path=HOUSING_PATH):
    os.makedirs(housing_path, exist_ok=True)
    #tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(DOWNLOAD_ROOT)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

# %%
fetch_housing_data()

# %%
import wget
URL = "https://github.com/thepisgahgeographer/ArcGIS_JS_API/blob/cebf11378fc11b459ea25e984561ca6c739a52ed/Add_Layers.html"
response = wget.download(URL)
Location = r"C:/"

def rawDL(URL, Location):
    print("test")




DOWNLOAD_ROOT = "https://github.com/thepisgahgeographer/ArcGIS_JS_API/blob/cebf11378fc11b459ea25e984561ca6c739a52ed/Add_Layers.html"
HOUSING_PATH = r"C:/Data"

def fetch_housing_data(housing_path=HOUSING_PATH):
    os.makedirs(housing_path, exist_ok=True)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(DOWNLOAD_ROOT)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

# %%
import pandas as pd

def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)


load_housing_data()
