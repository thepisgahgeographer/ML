# %%
height = int(input("What is your height"))

if height > 120:
    print("You can ride")
    age = int(input("What is your age?"))
    if age < 12:
        print("Five bucks")
    elif age >12 and age <18:
        print("Seven Bucks")
    else:
        print("Twelve Bucks")

else:
    print("Sorry you cannot ride")
# Out:
# You can ride
# Seven Bucks

# %%
7 % 2
# Out:
# 1

# %%
value = int(input("Pick a number"))

if value % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Odd Number

# %% [markdown]
# ### BMI = Weight/Height squared

# %%
weight = float(input("What is your weight"))
height = float(input("What is your height"))

bmi = round(weight / height**2)
if bmi < 18.5:
    print("Underweight")
elif bmi <25:
    print("Normal Weight")
else:
    print("Overweight")

print(bmi)
# Out:
# Underweight
# 5.0

# %%
year = int(input("Which year do you want to check?"))

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("Leap Year")
    else:
        print("Leap Year")
else:
    print("Not Leap")
# Out:
# Not Leap

# %%
size = input("Size Pizza?")
add_pep = input("Add Pepperoni?")
extra_cheese = input("Add Cheese?")

if size == "Large":
    if add_pep == "Yes":
        print("$28")
        if extra_cheese == "Yes":
            print("$29")

if size == "Medium":
    if add_pep == "Yes":
        print("$23")
        if extra_cheese == "Yes":
            print("$24")

if size == "Small":
    if add_pep == "Yes":
        print("$17")
        if extra_cheese == "Yes":
            print("$18")
# Out:
# $23

# %%
name = 'Dorian grey'
name_2 = "Wonder Woman"
final = name + name_2
final_name = final.lower()


T = final_name.count("t")
R = final_name.count("r")
U = final_name.count("u")
E = final_name.count("e")
true = T + R + U + E

L = final_name.count("l")
O = final_name.count("o")
V = final_name.count("v")
E = final_name.count("e")
love = L + O + V + E


percentage = true + love
percentage
# Out:
# 10

# %%
choice_1 = input("Go left or right")

if choice_1=="left":
    choice_2 = input("Wait or swim")
    if choice_2=="Wait":
        choice_3 = input("Pick a door")
        if choice_3=="Red":
            print("Game Over")
        elif choice_3=="Yellow":
            print("You Win")
        elif choice_3==-"Blue":
            print("Game Over")
        else:
            print("Game Over")
    else:
        print("Game Over")
else:
    print("Game Over")
# Out:
# You Win

# %%
import random

val = random.randint(0, 1)
if val == 1:
    print("Heads")
else:
    print("Tails")
# Out:
# Heads

# %%
pip install up42-py
# Out:
# ...
#   Obtaining dependency information for up42-py from https://files.pythonhosted.org/packages/a6/25/7e399b5abf9974cca7829f01942436fbe654672634a903f1922b1a6cdbdf/up42_py-0.32.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for requests==2.31.0 from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
# ...
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# ...
#   Using cached tenacity-8.2.2-py3-none-any.whl (24 kB)
# ...
#   Obtaining dependency information for tqdm==4.66.0 from https://files.pythonhosted.org/packages/a5/d6/502a859bac4ad5e274255576cd3e15ca273cdb91731bc39fb840dd422ee9/tqdm-4.66.0-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/57.5 kB ? eta -:--:--
#      -------------------- ----------------- 30.7/57.5 kB 660.6 kB/s eta 0:00:01
#      ---------------------------------------- 57.5/57.5 kB 1.0 MB/s eta 0:00:00
# ...

# %%
import up42

# %%
login = up42.authenticate(
    project_id="3421f14c-a592-4942-899e-72c3576797be",
    project_api_key="P7zmaVfs.iz45H7PmckSaZ0pH8HGc7CPcLHVN11m8T5o"
)

login
# Out:
# 2023-09-28 13:25:25,592 - Authentication with UP42 successful!

# %%
catalog = up42.initialize_catalog()
catalog
# Out:
# Catalog(auth=UP42ProjectAuth(project_id=3421f14c-a592-4942-899e-72c3576797be))

# %%
adj = input("Adjective")
verb1 = input("fun, borint, etc")
verb2 = input("sir, maam, etc")

madlib = f"Computer programming is so {adj}! It makes me so excited. I love to {verb1}.  Stay hydrated {verb2}"

print(madlib)
# Out:
#   Cell In[10], line 5
#     madlib = f"Computer programming is so {adj}! It makes me so excited \
#              ^
# SyntaxError: unterminated string literal (detected at line 5)

# %%
import random

def guess(x):
    random_number = random.randint(1, x)
    guess = 0
    while guess != random_number:
        guess = int(input(f"Between 1 and {x}"))
        if guess < random_number:
            print("Too low")
        elif guess > random_number:
            print("Too high")
    print("True")


guess(10)
# Out:
# Too low
# Too low
# Too low
# Too low
# Too low
# True
